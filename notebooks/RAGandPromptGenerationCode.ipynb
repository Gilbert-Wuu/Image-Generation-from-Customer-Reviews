# %% [markdown]
# # **Final Project**

# %%
# !pip install -r requirements.txt
# !pip install ipykernel langchain_experimental llama-index-vector-stores-pinecone ipykernel PyMuPDF pinecone-client pypdf faiss-cpu langchain_community transformers sentence_transformers
# !pip install llama_index.embeddings.huggingface

# %%
import io
import json
import math
import os
import re
import sqlite3
import time

import datasets
import dotenv
import faiss
import fitz
import huggingface_hub
import langchain
import langchain_community
import nltk
import numpy as np
import openai
import pandas as pd
import pinecone
import pypdf
import requests
import torch
import transformers
from dotenv import load_dotenv
from langchain_experimental.text_splitter import SemanticChunker
from langchain_openai.embeddings import OpenAIEmbeddings
from llama_index.core import (SimpleDirectoryReader, StorageContext,
                              VectorStoreIndex)
from llama_index.core.extractors import (QuestionsAnsweredExtractor,
                                         TitleExtractor)
from llama_index.core.ingestion import IngestionPipeline
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.node_parser import TokenTextSplitter
from llama_index.core.schema import TextNode
# sentence transformers
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI
from llama_index.vector_stores.pinecone import PineconeVectorStore
from pinecone import Pinecone, ServerlessSpec
from sentence_transformers import SentenceTransformer
from tqdm import tqdm

# %%
load_dotenv()

#access_endpoint_api_key =os.getenv('access_endpoint_api_key')
openai_api_key = 'Api Key placeholder'
pinecone_api_key='Api Key placeholder'
# environment =os.getenv('PINECONE_ENV')
# HF_TOKEN = os.getenv('HF_TOKEN')

# configure Pinecone client
pc = Pinecone(api_key=pinecone_api_key)

# %%
doc = fitz.open("Product_review.pdf")

# %% [markdown]
# ### **Token chunking method to chunk the text data:**
#
# - [Token chunking](https://python.langchain.com/docs/modules/data_connection/document_transformers/split_by_token)

# %% [markdown]
# ##### Choose a type of chunker (From langchain):

# %%
# # parser to split up product review:
text_parser = TokenTextSplitter(
    chunk_size=1024
)

# %%
text_chunks = []
doc_idxs = []


for doc_idx, page in enumerate(doc):
    page_text = page.get_text("text")
    cur_text_chunks = text_parser.split_text(page_text)
    text_chunks.extend(cur_text_chunks)
    doc_idxs.extend([doc_idx] * len(cur_text_chunks))

# %%
text_chunks
# Out:
# ['Product 1: Mesh Office Chair Mid Back Swivel Ergonomic Home \nDesk Chair with Flip-up Arms \n \nDescription:  \n● The computer desk chair is made of the high-density and breathable mesh \nback with lumbar support and thick cushion to provide you the most \ncomfortable posture. The thickened explosion-proof seat plate give you more \ncomfort and double coverage. Max capacity: 300 lbs. \n● The mesh office chair comes with adjustable padded armrests which can be \nflipped up or down. It saves your space and can be easily stored. Suitable for \noffice, living room, study room, meeting room, etc. \n● Pneumatic seat height adjustment; Tilt lock function(angle adjustable); 360 \ndegree swivel; Solid rolling silencer casters for smooth movement. \n● We offer installation instruction and video to help you. It usually takes about \n10-20 minutes to assemble. If you have any questions, please feel free to \ncontact us. \nReviews: \n● Easy to assemble and made with decent materials. And it is comfortable \nlooks great. \n● Cool chair, easy to put together and comfortable. Thank you \n● Good value quality item \n● The chair I ordered is in great condition it shipped fast and arrived sooner \nthan I thought thank you very much!   \n● Made well, brand new price was right and looks great also. \n● Nice chair at a nice price and prompt delivery \n● Good product \n● 5-star seller, chair and shipping!!!!! Thank you!!!! \n● A great seller shipped quickly item as described \n● great seller got my package very fast WOW   \n● Very pleased with this purchase! Came early too! I recommend this seller \nA+++ would purchase from this seller again. \n● Great seller. Super fast shipping! \n● a nice seller and a quick shipper. thank you. \n● Arrived well packed and on time. \n● Fast shipping \n● I got this package today..TK soo much.. \n● NICE \nActual image:',
#  "Product 2: Dell S2721QS Monitor 27 Inch, 4K UHD \n(3840 x 2160) IPS Display, Ultra-Thin Bezel, AMD \nFreeSync, HDMI, DisplayPort, VESA Certified - Silver \n \nDescription:  \nThe Dell S2721QS Monitor provides stunning visuals. It has a 27-inch 4K UHD IPS \ndisplay that provides breathtaking clarity and vibrant colors. The ultra-thin bezel \ndesign provides an immersive viewing experience. Enjoy tear-free gameplay and \nsmooth visuals with AMD FreeSync technology. With HDMI and DisplayPort \nchoices, you can easily connect. This feature-rich display for work or play will \nenhance your visual experience. \n \nReviews: \n● I have two Dell 27 inch monitors. This one was my second purchase. It's easy to set \nup. It has a sturdy build. Excellent connectivity and the additional USB ports and \nsound port make it a perfect addition to my desktop. Color is accurate, picture quality \nis bright and clear. Use both dell monitors on a Mini-PC primarily as a photo editing \nplatform, but the 4k allows me to work with high quality video as well. I have no \ncomplaints. I would buy this again if I needed to.",
#  '● \nDell has become my go to for monitors. The build quality is always high, the picture is \nclear and it works well. I have this monitor setup with an Anker USB-C dock hooked \nup to an M1 MacBook Air. No, it cannot do multiple external monitors, but a single \nlarge monitor is what my wife had with her old iMac 27" and this monitor does not \ndisappoint. No, it\'s not the highest in any spec, but it\'s a solid choice for standard \nproductivity tasks like documents and some media work like photos and videos. The \nquality and functionality represents a good value for the money. \n● \nThis monitor is superb; more than a bargain at the price I paid for it ($243.79, \nincluding shipping). The default setting of 75 for brightness is extremely powerful; I \nturned it down to 50 and it\'s still quite bright. The resolution is incredibly sharp and \ncolors are true and accurate. The anti-glare coating is very effective. It\'s hard to find \na flaw here, but if I were to mention one, this monitor does NOT support USB-C / \nThunderbolt. Your connectivity is limited to HDMI and DisplayPort. \n● \nIm a photographer who is frustrated editing on this monitor because it is not color-\ncalibrated. It doesn\'t even have a color-accurate mode, even my brother\'s cheaper \ngaming monitor has a color-accurate mode. This issue isn\'t why I\'m giving the \nmonitor 2 stars however, I should have done the research I just saw it had 99% color \ngamut and thought it would suffice. The reason for the 2 stars is the constant issues \nthe monitor is having. From causing my laptop to not start up correctly, to randomly \ndisconnecting the monitor is always frustrating to deal with. I have to have it \ndisconnected when I turn on my laptop because if it\'s connected my laptop doesn\'t \nboot up correctly and gives me the BSOD, sometimes it disconnects, and unplugging \nand plugging it back in won\'t fix the issue I have to restart my laptop for it to work \ncorrectly again. I regret buying it, especially for the +$300 price tag at the time. I \nwould have been better off with another monitor. \n● \nThis would be a great monitor but i has trouble with my M1 (Silicon) MacBook Pro. \nThe display flickers when certain images/colors/brightness are on screen. Google it \nand you will see a ton of M series MacBook users with this problem, with no solution \nfrom Dell or Apple, and Dell says officially they do not support Mac at all. I had zero \nproblems with it and my older Intel-based Mac Pro (booting into Mac OS or \nWindows). But the flicker occurs when using the M1 MacBook with no real solution \nanywhere except "it\'s not compatible" \n● \nThe monitor was great for the first few months and then suddenly started flashing \nafter i not using it for 10 days.I  got an immediate response from customer service to \nhave the unit replaced. However, they sent me a refurbished monitor that arrived \nbroken. All in all just a waste of time for me. Its cheap but just not worth the hassle. \nSpend a little more for peace of mind.  Also, the picture quality isn\'t the best. You can \npick out pixels in the display \n● \nFirst off, I really do like this monitor, now that I have gotten it tweaked in for my use. \nIt is actually a simple, straight forward machine, if only they had included even \nrudimentary instructions in the box, which is the reason for giving it only 4 stars, \nwhen it deserves 5 stars...The pictorial instructions got me hooked right up, but I \nalmost returned it, because I could not figure out how to turn it on!!! After about 35 \nminutes of frustration, including online research, I ran my fingers all along the bottom \nand top of the machine, and felt a little bump at the bottom right, and luckily turned it \non. There is no icon to tell you this switch exists, and the instructions show a picture',
#  'of the power button where the headphone jack is!! ... I am using this monitor for my \ndigital audio recording workstation, with a Mac M4 Pro computer. The screen was too \nbright for my tastes, but my Mac had some screen adjustments which allowed me to \nwarm the screen up, but then everything looked kind of yellow, which was not \nsatisfying either. Again, I searched the bottom of the machine, thinking that there \nHAD to be some kind of adjustment to lower the brightness, and I felt 3 little bumps, \nnear the elusive power switch, but I thought they were just part of the trim, and that \nno one would make a machine with such inconvenient controls.. but no, they were \nadjustment buttons!! I only found these after a few days of frustration, all of which \nwas needless, if instructions had been included... Anyway, at this point, I am totally \nhappy with this monitor- very crisp, sharp, pleasant picture, now that I have lowered \nthe brightness.. I love the fact that almost the entire screen is the picture, with a \nborder that is about 3/8" at the top and sides, and about 3/4" at the bottom. I got this \non sale for $213.00, and for that price it was a bargain, but the current $279.00 price \nis still probably worth it, I think. It serves my needs perfectly. \n● \nThis is a decent monitor that was on sale when I needed a new wide screen monitor. \nLooking back though, I would have bought something else since it makes my multiple \nmonitor set up a bit weird due to differences in physical sizes and resolutions. Since \nthis has the same resolution as the smaller monitors I already owned but is physically \nbigger, it ends up with everything on this monitor looking larger than it does on all my \nother monitors. This was always going to be a second wide screen monitor and I \nbought a bigger/nicer widescreen monitor that has a much higher resolution since I \nbought this one. That new one doesn\'t have this issue so I can move things just fine \nbetween my older monitors and that one without them being a noticeably different \nsize. I refer to this one as my old man monitor now, good for quickly blowing things \nup to a larger size but not so much for multitasking using multiple windows on one \nmonitor like the newer monitor I bought. In a four monitor set up with two very old \nmonitors to be replaced before this one it will still get plenty of use though. \n● \nI\'m really happy with the quality of the images, especially when viewed from various \nangles other than head-on. I knew that the sound system was not great, but not \nexpecting that even with all possible interventions in Windows and on the monitor \nitself that I began to wonder if I should also buy a pair of hearing aids. CONTRARY \nto many reviews that wrote disparagingly about the so-called wobbly stand, I found it \nwobbly only before I noticed on the provided set-up sheet of instructions that it was \nnecessary to tighten the connection between the base and the post holding the \nmonitor itself by tightening the screw that is factory installed for this purpose. Tighten \nthat screw and the post is absolutely rigid. \n● \ni had bought this for my son\'s birthday. here are my comments: \n- the screen is an LCD. i know that i wasn\'t going to get a big fancy OLED this size \nfor under a thousand dollars, but i feel like the manufacurer had deliberately avoided \nmentioning the screen type. however, the color quality and visual quality are much \nbetter than my previous setup (a 41 inch 30hz LCD samsung smart TV). \n-the volume is probably the best thing about this: loud sounds are hushed down and \nbackground sounds are very easy to hear, ideal for horror or stealth games. i actually \nhave the volume at 1% because xbox doesn\'t seem to have a native volume control, \nso i\'m sure the speakers could be deafening if you wanted.',
#  '-the curved screen makes it easier to sit closer to the screen without hurting your \neyes, and while the colors don\'t go very dark, lighter off-whites are very easy to spot. \ni can\'t wait to use this for digital drawing. \nassembly also just involved clicking together a two-piece stand and inserting cables. \nthe monitor even moves a bit to make cable insertion easier. \nbut my favorite thing is that this product is "dumb", it doesn\'t have any eavesdropping \nvirtual assistants, unneeded internet connectivity, or ads. i bet that it was only $360 \nbecause dell marketed this as a "monitor" rather than a "home entertainment \nplatform", however it still has the quality graphics one would expect from a modern \nappliance. \n \ni am a bit mad at amazon for not putting the product into an anonymous brown box \nbefore leaving it on my doorstep at 3:30 PM, but i can\'t blame the seller or \nmanufacturer for that. \nActual image:',
#  'Product 3: HIGH VISIBILITY INSULATED HI VIS REFLECTIVE \nROAD WORK SAFETY BOMBER JACKET COAT \n \nDescription:  \nPyramex RJ3210 HIGH VISIBILITY LIME GREEN COAT Hi Vis CLASS 3 Insulated \nSafety Bomber Reflective Winter Work Jacket With Quilted Liner For ROAD WORK Or \nConstruction, Sizes: Small - 6XLarge \nThe RJ3210 by Pyramex is a class 3 weatherproof bomber jacket with a quilted liner and \nblack bottom. This jacket has a weatherproof polyester shell with a quilted liner. There is \nalso an attachable hood that is easy to conceal. Zipper front closure runs through the black \nbottom, while sweat-proof elastic lining clasps the waist and wrist cuffs. 5 Pockets are \nfound throughout the jacket with 4 in the front and 1 and within the inside. Mic tabs and \npencil pockets are found in the front along with a clear ID badge holder that can also fit a \nradio or cell phone. This hi vis workwear meets ANSI/ISEA 107-2015 Type R, Class 3 \nStandards.  \nFeatures: \n● ANSI/ISEA 107-2015 Type R, Class 3 \n● Weatherproof Polyester Shell with Quilted Lining \n● Weatherproof Elastic Band at the Waist and Wrists \n● 2" Silver Reflective Material \n● Concealed Hood \n● Max 25 Washes \n● Zipper Front Closure \n● 5 Pockets: 4 Outside, 1 Inside \n● Cell Phone/Radio Chest Pocket with Clear Panel on Outside Shell \n● Mic Tabs and Pencil Pocket \n● Available in Color: Hi Vis Lime/Black Bottom \n● Available in Sizes: MD, LG, XL, 2XL, 3XL, 4XL, 5XL \n●',
#  "Reviews: \n \n1. The jacket is as described, time will be the test of quality. Not fond of the hood as it \nmakes collar too bulkin when folded. \n2. My Husband loves this jacket. Its comfortable and warm. Delivered quickly and is \ngood quality material. \n3. Nice coat , runs true to size , good price \n4. Nice warm jacket. Hood tucks in collar. Would buy again. Fast shipping \n5. Thanks so much for the speedy fast delivery the jacket looks great it's insulated and \ncan be used as a rain coat. Thanks again \n6. Fasts shipping. Great product. Great price. Not a huge fan of the hood, it's virtually \nuseless, but at least it had a hideaway in the back in the collar so you can make it \ndisappear. \n7. Absolutely love this jacket. It is very warm and very well made. For the price you can’t \nbeat it. If you are looking for a good reflective work jacket you can’t go wrong with this \none. My only complaint would be the way the hood is made. The hood isn’t insulated \nnor is it sewn all the way across the bottom where it connects to the coat. Oh yeah \nthis item arrived within 3 days of purchase. So AAA+++ on shipping. \n8. Good looking, great quality, excellent condition, worth the money. \n9. Very good quality material, not too big not too small, just a perfect fit, super fast \nshipping, very happy with my purchase.. thank you!! \n10. I ordered this Jacket and i got Damaged ans zipper not working and i have contacted \nthe seller i send him couple messages and still not respond i have to call ebay and do \nnext step Never Order from this i not recommended this seller sorry but i have to tell \ntruth. \n11. hoody is a little less quality..it will do,,,,",
#  '12. I ordered a 4 x but got a 3 x instead. But it is a nice jacket well pleased with the way \nthe jacket is made \n \nActual image:']

# %%
nodes = []

for idx, text_chunk in enumerate(text_chunks):
    node = TextNode(
        text=text_chunk,
    )
    src_doc_idx = doc_idxs[idx]
    src_page = doc[src_doc_idx]
    nodes.append(node)

# %% [markdown]
# ### **Create the vector store using chosen similarity metrics:**

# %%
use_serverless = True #os.environ.get("USE_SERVERLESS", "False").lower() == "true"

# %%
spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    )

# specify the Pinecone environment to use:
if use_serverless:
    spec = pinecone.ServerlessSpec(cloud='aws', region="us-east-1")
else:
   spec = pinecone.PodSpec(environment=environment)

# %%
# Name our Pinecone Index:
# index_name = "hw02-rag"
index_name = "hw04"

# If a Pinecone index of the same name already exists, delete it:
if index_name in pc.list_indexes().names():
    pc.delete_index(index_name)

# %% [markdown]
# ### **choose a similarity metric to use for the vector store:**

# %%
# define similarity and additional parameters for the vector store index:
dimensions = 1536 #364  #1536 #768              # the dimensions of the index need to align with the LLM we are using for the RAG system. For example, if using openAI then dimenion = 1536. If using Llama2, then dimension = 384.

# "dotproduct" is one similarity metric we can for the vector store index. We can use different distance metrics to measure the similarity between vector embeddings and user queries. This is where we define what similarity metric we are going to use for the vector store.
# "cosine" is another similarity metric we can use for the vector store index.
# "euclidean" is another similarity metric we can use for the vector store index.

pc.create_index(
    name=index_name,
    dimension=dimensions,
    metric="cosine",          # we can use different distance metrics to measure the similarity between vector embeddings and user queries. this is where we define what similarity metric we are going to use for the vector store.
    spec=spec
)

# wait for index to be ready before connecting
while not pc.describe_index(index_name).status['ready']:
   time.sleep(1)

for index in pc.list_indexes():
    print(index['name'])


pc.describe_index("hw04")


pc_index = pc.Index(index_name)  # create an index to use in the vector store


vector_store = PineconeVectorStore(pinecone_index=pc_index)    # this function creates a vector store where we will add and store embeddings
# Out:
# hw04
# hw02-rag
# hw02

# %%
pc_index = pc.Index(index_name)  # create an index to use in the vector store
vector_store = PineconeVectorStore(pinecone_index=pc_index)    # this function creates a vector store where we will add and store embeddings

# %%
pc_index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %%
llm = OpenAI(model="gpt-3.5-turbo",
             api_key=openai_api_key)

extractors = [
    TitleExtractor(nodes=5, llm=llm),
    QuestionsAnsweredExtractor(questions=3, llm=llm),
]

pipeline = IngestionPipeline(
    transformations=extractors,
)
nodes = await pipeline.arun(nodes=nodes, in_place=False)
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  4.23it/s]
# 100%|██████████| 8/8 [00:02<00:00,  3.62it/s]

# %% [markdown]
# ### ***choose an embedding model to use for the vector store:**

# %% [markdown]
# #### **OpenAI Embeddings**

# %%
model_ada="text-embedding-ada-002"
small_txt_embedmodel_="text-embedding-3-small"

# %%
embed_model = OpenAIEmbedding(model="text-embedding-3-small", api_key=openai_api_key)

for node in nodes:
    node_embedding = embed_model.get_text_embedding(
        node.get_content(metadata_mode="all")
    )
    node.embedding = node_embedding

# %% [markdown]
# ### **load the embeddings into the vector store (e.g. create a vector store):**

# %%
vector_store.add(nodes)
# Out:
# Upserted vectors: 100%|██████████| 8/8 [00:00<00:00, 29.09it/s]
# ['a6473a45-e86f-4211-89fb-e51ae7293a95',
#  '032f414a-7918-4a14-9f46-8e2c2f12a676',
#  'cb2d9631-221f-4cc7-be78-46d2edf61428',
#  'cf1a1fb3-d0ef-43d8-8f9d-ae6a92d2c7ed',
#  'e351fbc3-6448-4a9f-9950-990d1581ed52',
#  'f6b38dc0-0749-4de0-b388-0588f21f81ee',
#  'd77be865-3ceb-4a88-815c-3856a174fa32',
#  '7086d367-115f-4871-8905-0816c02604db']

# %%
pc_index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %%
print(nodes[0].metadata)
# Out:
# {'document_title': '"Comprehensive Review of Office Chairs and Monitors: Comfort, Visuals, Connectivity, and Customer Service"', 'questions_this_excerpt_can_answer': '1. How long does it typically take to assemble the Mesh Office Chair Mid Back Swivel Ergonomic Home Desk Chair with Flip-up Arms?\n2. What are some common positive reviews from customers who have purchased the Mesh Office Chair?\n3. What specific features does the Mesh Office Chair offer, such as adjustable armrests and pneumatic seat height adjustment?'}

# %%
nodes
# Out:
# [TextNode(id_='a6473a45-e86f-4211-89fb-e51ae7293a95', embedding=[0.015835769474506378, 0.043330978602170944, 0.00570418406277895, 0.021420542150735855, 0.0021953301038593054, -0.045804932713508606, -0.024372143670916557, 0.03608056902885437, 0.03485583886504173, 0.02706655114889145, 0.021138854324817657, -0.027605433017015457, -0.005529659800231457, -0.06025675684213638, -0.010838868096470833, 0.048523835837841034, -0.006833998020738363, -0.013055630959570408, -0.026699131354689598, 0.014733511954545975, 0.030103884637355804, 0.0432329997420311, 0.005841966252774, 0.01987738162279129, -0.03571315109729767, 0.031010184437036514, -0.00830367486923933, -0.04849934205412865, -0.025278445333242416, -0.023453595116734505, 0.008897669613361359, -0.02922207862138748, 0.021249080076813698, -0.03103468008339405, -0.029809948056936264, 0.013949683867394924, -0.045217063277959824, 0.01084499154239893, 0.013092372566461563, -0.029516013339161873, 0.04928316920995712, 0.062265314161777496, 0.017244210466742516, -0.025131477043032646, 0.004458020441234112, -0.011604324914515018, -0.0013074001763015985, 0.004216135945171118, 0.003661945229396224, 0.034684378653764725, -0.04274310544133186, 0.059423938393592834, 0.0037446145433932543, 0.016141952946782112, 0.002144809812307358, 0.020465252920985222, -0.0049019851721823215, 0.004130404908210039, -0.0005228069494478405, -0.016411393880844116, 0.028242293745279312, -0.06740918755531311, -0.013239339925348759, 0.04171433299779892, -0.0008825716795399785, -0.06971167773008347, 0.005517412442713976, 0.0043477946892380714, -0.016656339168548584, -0.042571645230054855, 0.014219124801456928, 0.040538590401411057, -0.0038517785724252462, -0.010600045323371887, 0.0025535637978464365, -0.01668083481490612, 0.038432054221630096, -0.03855452686548233, -0.012443264946341515, 0.03960779681801796, -0.097537562251091, -0.003845654893666506, -0.04842585697770119, 0.010600045323371887, -0.04945462942123413, -0.03169603273272514, -0.03081422857940197, -0.012081969529390335, -0.06412690877914429, -0.00846901349723339, -0.04898923262953758, 0.0049417889676988125, 0.03147558122873306, -0.008946659043431282, 0.05785628408193588, -0.021604251116514206, -0.011359378695487976, 0.008205696940422058, -0.04154286906123161, 0.027629926800727844, 0.08680891990661621, -0.0009040044387802482, -0.03982824832201004, -0.011683932505548, -0.007979121059179306, -0.011886012740433216, 0.0060409847646951675, -0.030912205576896667, -0.01679106056690216, -0.003606832353398204, -0.033410657197237015, -0.015750039368867874, -0.03225940838456154, 0.033484142273664474, -0.002443338045850396, 0.030348829925060272, 0.007011584006249905, 0.045364029705524445, -0.028977131471037865, -0.0067605143412947655, -0.02067345567047596, 0.017452415078878403, 0.035737644881010056, -0.02721351943910122, 0.008168954402208328, -0.01693802699446678, -0.04624583572149277, -0.028903648257255554, -0.09386336803436279, 0.01170230284333229, 0.04585392400622368, -0.01686454378068447, 0.031524572521448135, -0.034610893577337265, -0.039656784385442734, 0.026135755702853203, -0.019350746646523476, -0.0524674691259861, -0.006233879830688238, -0.010851114988327026, -0.019277263432741165, -0.059717874974012375, -0.022045155987143517, -0.008315922692418098, -0.015835769474506378, 0.006901358254253864, 0.03808913007378578, 0.009969308972358704, -0.01969367265701294, 0.05952191725373268, -0.009234470315277576, -0.00479482114315033, 0.0009124244679696858, -0.0015967427752912045, 0.012761695310473442, -0.03720732405781746, 0.06309813261032104, 0.02209414355456829, -0.009620260447263718, 0.01117566879838705, 0.04538852348923683, -0.016337908804416656, 0.019460972398519516, -0.02721351943910122, 0.04298805072903633, 0.03394953906536102, -0.03781968727707863, -0.003279216820374131, -0.046637751162052155, -0.014721265062689781, 0.06657636910676956, 0.014231372624635696, 0.0548679418861866, 0.04142039641737938, 0.07789288461208344, -0.011530840769410133, 0.0008021987159736454, 0. ...
#  TextNode(id_='032f414a-7918-4a14-9f46-8e2c2f12a676', embedding=[-0.03341470658779144, 0.009367969818413258, 0.0007550219306722283, 0.02330595999956131, 0.02128876931965351, -0.008194124326109886, 0.008940598927438259, 0.01233107503503561, 0.03592194989323616, 0.02239423431456089, 0.03628663718700409, -0.036377809941768646, -0.05456671491265297, 0.011692867614328861, 0.024183494970202446, 0.021664856001734734, -0.004302200395613909, -0.026895875111222267, -0.040412191301584244, 0.0007365025230683386, 0.048868436366319656, 0.047728780657052994, 0.002853413112461567, 0.01764187030494213, 0.018371250480413437, -0.020730337128043175, -0.037380706518888474, -0.01586400717496872, -0.01891828514635563, -0.011105945333838463, 0.011180022731423378, -0.04478846862912178, -0.008308090269565582, -0.05506816506385803, -0.027260564267635345, 0.02773922123014927, -0.032434601336717606, 0.010843824595212936, -0.026075322180986404, -0.005433308891952038, 0.006342184264212847, 0.09162832051515579, 0.04508478194475174, -0.022234683856368065, 0.02589297853410244, -0.04052615910768509, -0.02678190916776657, -0.006963296327739954, 0.005307946354150772, 0.03343749791383743, -0.027351737022399902, 0.06186051294207573, 0.042531952261924744, 0.014131731353700161, 0.01923738792538643, 0.03585356846451759, 0.010165728628635406, -0.040640123188495636, 0.015898197889328003, -0.043101780116558075, 0.03150008246302605, -0.03893063962459564, -0.01491809356957674, 0.08337721228599548, -0.030406014993786812, -0.019545095041394234, 0.00874685775488615, 0.003675389802083373, -0.01919180154800415, -0.03893063962459564, 0.0018305720295757055, 0.04109598696231842, 0.002783609088510275, 0.046452365815639496, 0.00873546116054058, -0.012376661412417889, 0.03514698147773743, -0.0333007387816906, -0.03617267310619354, 0.026417220011353493, -0.04025264084339142, 0.027488496154546738, -0.06053851172327995, 0.0137328514829278, -0.031841982156038284, 0.01855359598994255, -0.0014459382509812713, -0.005168338771909475, -0.07594665884971619, 0.04451495409011841, -0.0038634329102933407, 0.011954988352954388, 0.07129686325788498, -0.003168242983520031, 0.05210506170988083, 0.016422439366579056, 0.01134527288377285, -0.00437912717461586, -0.0630001649260521, 0.0277848057448864, -0.010843824595212936, -0.0017978069372475147, -0.0702027902007103, 0.0041426485404372215, 0.02892446145415306, -0.01655919849872589, 0.03289046511054039, 0.00776105560362339, 0.05370057746767998, 0.0043050493113696575, -0.04592812433838844, 0.0016923887887969613, -0.028536979109048843, 0.03742629289627075, 0.011339574120938778, -0.05511375144124031, -0.05670926719903946, 0.01430267933756113, -0.006307994481176138, -0.03630943223834038, -0.008843728341162205, 0.026576772332191467, 0.028787704184651375, -0.027306150645017624, 0.026873081922531128, -0.04091364145278931, 0.015875404700636864, -0.0405033640563488, -0.03355146571993828, -0.035511672496795654, 0.018975267186760902, -0.004652644507586956, 0.024502597749233246, -0.03318677470088005, 0.005262360442429781, 0.002614085329696536, -0.03491905331611633, -0.0402982272207737, -0.0029545575380325317, -0.00468113599345088, -0.03496463596820831, 0.002292132470756769, -0.001403201138600707, 0.012308281846344471, -0.02584739215672016, -0.03200153261423111, -0.0166503693908453, 0.010308186523616314, -0.031796395778656006, 0.017824215814471245, -0.03842918947339058, 0.01739114709198475, -0.009031771682202816, -0.02860535867512226, -0.0027551178354769945, -0.012581799179315567, 0.06600885838270187, 0.005621351767331362, -0.009601599536836147, -0.024776116013526917, 0.00975545309484005, -0.0005331452121026814, 0.0014972226927056909, -0.006598606705665588, -0.027875978499650955, -0.017117628827691078, -0.003706730203703046, 0.017288576811552048, -0.06432216614484787, 0.012889506295323372, 0.032411810010671616, 0.05050954222679138, 0.038269639015197754, 0.04082246869802475, 0.0926768034696579, 0.0050258818082511425, 0.011829626746475697, -0.012821126729249954, 0.0099 ...
#  TextNode(id_='cb2d9631-221f-4cc7-be78-46d2edf61428', embedding=[-0.0069394162856042385, 0.042465802282094955, -0.04531696066260338, 0.0007569104200229049, -0.010959137231111526, -0.04320600628852844, 0.012583475559949875, 0.0274012703448534, 0.02104099653661251, 0.047976210713386536, 0.02042415924370289, 0.006442519836127758, -0.052170705050230026, 0.011692488566040993, 0.011863832361996174, 0.020561233162879944, -0.045179884880781174, -0.02652399241924286, -0.026866678148508072, 0.012871332466602325, 0.057681113481521606, 0.04501539468765259, 0.04010811448097229, 0.03679089993238449, 0.006408251356333494, 0.006182077806442976, -0.0325964093208313, -0.04888090491294861, 0.0070799184031784534, -0.005219126585870981, 0.012487522326409817, -0.02734644152224064, -0.010890600271522999, -0.05392526090145111, -0.0013895967276766896, 0.020095178857445717, -0.021452220156788826, -0.02575637213885784, -0.027839910238981247, -3.9141308661783114e-05, -0.025646712630987167, 0.08131282776594162, 0.05702315643429756, 0.008251908235251904, -0.000989509397186339, -0.04896315187215805, -0.05400750786066055, 0.013782880268990993, -0.021109532564878464, 0.010129834525287151, -0.05088220164179802, 0.07911963015794754, 0.017367389053106308, 0.04720859229564667, -0.02988232672214508, -0.020095178857445717, 0.015585415065288544, -0.008793354034423828, -0.028031814843416214, 0.005548106040805578, 0.06957921385765076, -0.02409776672720909, -0.007689901627600193, 0.012268203310668468, -0.009177164174616337, -0.028621237725019455, -0.005311652086675167, -0.006843463983386755, -0.01106194406747818, -0.04125954210758209, 0.019711369648575783, 0.0160788856446743, -0.01411871425807476, -0.013419631868600845, -0.013652659021317959, 0.0209861658513546, 0.024385623633861542, -0.00010307389311492443, -0.02878572791814804, 0.03988879546523094, -0.03347368910908699, 0.028922801837325096, -0.044357433915138245, -0.023097120225429535, -0.011082504875957966, 0.03171912953257561, -0.05291090905666351, -0.03509117290377617, -0.04424777626991272, -0.04306893050670624, -0.01855994015932083, 0.0187518447637558, 0.04507022351026535, 0.009026382118463516, 0.016202252358198166, -0.03366559371352196, -0.06502833217382431, 0.003759278915822506, -0.03234967589378357, 0.016476402059197426, -0.008484935387969017, 0.03267865255475044, -0.04564594104886055, -0.0050477827899158, 0.05164982005953789, -0.020862799137830734, 0.012823356315493584, 0.026112766936421394, 0.012898747809231281, 0.03632484748959541, -0.01577731966972351, 0.0033823230769485235, -0.028867973014712334, 0.04013552889227867, -0.030540285632014275, -0.01256976742297411, -0.07385595142841339, 0.06925023347139359, -0.006267749238759279, -0.05943567305803299, -0.023686541244387627, 0.023946983739733696, 0.016092592850327492, -0.003920341841876507, 0.03563947230577469, -0.03988879546523094, 0.03240450471639633, -0.00601758761331439, -0.04671512171626091, -0.04098539426922798, 0.03632484748959541, 0.006685827858746052, 0.028895387426018715, -0.048497095704078674, -0.0064836423844099045, -0.027743957936763763, -0.027140827849507332, -0.007278676610440016, -0.014543646015226841, 0.02486538514494896, -0.027771372348070145, -0.03188361972570419, 0.0447138287127018, -0.013570413924753666, -0.03624260053038597, 0.011719902977347374, 0.028840556740760803, 0.02490650862455368, -0.04372689127922058, 0.01580473594367504, 0.014283203519880772, 0.01847769506275654, -0.015379803255200386, -0.036900561302900314, 0.0656314566731453, -0.04224648326635361, 0.06332860141992569, 0.03961464390158653, -0.050169412046670914, -0.024454161524772644, 0.011390923522412777, 0.005979892332106829, 0.010870038531720638, -0.0005611503147520125, -0.020259669050574303, 0.039176005870103836, -0.017627831548452377, -0.028840556740760803, -0.07177241146564484, -0.0040505630895495415, 0.012912455014884472, 0.008875599130988121, 0.04090314731001854, 6.644919631071389e-05, 0.02848416194319725, -0.004204772412776947, -0.010294324718415737, -0.02958076260983 ...
#  TextNode(id_='cf1a1fb3-d0ef-43d8-8f9d-ae6a92d2c7ed', embedding=[0.0033057851251214743, 0.04333610087633133, -0.04977444186806679, -0.0011557616526260972, -0.008582049049437046, -0.01901187375187874, 0.017178533598780632, 0.02604207955300808, 0.010451477952301502, 0.02676386758685112, 0.048475224524736404, -0.013923274353146553, -0.08390054106712341, 0.06715507805347443, 0.04786892235279083, 0.031210076063871384, -0.023227110505104065, -0.03857230395078659, -0.06334403902292252, -0.02036883309483528, 0.06628893315792084, 0.032798007130622864, 0.015258580446243286, 0.02451189234852791, -0.013215922750532627, -0.023140495643019676, -0.011267097666859627, -0.024165432900190353, 0.0021419033873826265, -0.004070879425853491, 0.014746111817657948, -0.035742901265621185, -0.00941210426390171, -0.0710238516330719, -0.020282218232750893, -0.02741347625851631, -0.01889638788998127, -0.04815763980150223, 0.0062578944489359856, -0.0290591511875391, 0.015951495617628098, 0.05970623344182968, 0.031845249235630035, 0.014724457636475563, 0.008950160816311836, -0.01961817406117916, -0.0504673570394516, 0.015893753618001938, -0.04815763980150223, 0.02669168822467327, -0.04171929880976677, 0.07079288363456726, 0.01723627746105194, 0.040564436465501785, 0.03464578464627266, -0.034905627369880676, 0.014695586636662483, 0.0032877405174076557, 0.009635858237743378, -0.010992818512022495, 0.028193006291985512, -0.007535457611083984, -0.027095889672636986, -0.006763145327568054, 0.006954418960958719, -0.026561766862869263, -0.008791367523372173, -0.011909487657248974, 0.006911111995577812, -0.03868779167532921, 0.04062218219041824, 0.013432458974421024, -0.0394095778465271, 0.00157890934497118, -0.007918004877865314, 0.028885921463370323, 0.009585333056747913, -0.02599877305328846, -0.04463531821966171, 0.04122848063707352, -0.046078890562057495, 0.028943665325641632, -0.05196867510676384, -0.0024594897404313087, -0.024973835796117783, 0.021884586662054062, -0.019964631646871567, -0.009051211178302765, -0.023472517728805542, -0.00900790374726057, -0.041979141533374786, 0.02744234725832939, 0.05035187304019928, 0.0071673463098704815, -0.003244433319196105, -0.032653652131557465, -0.05817604437470436, 0.019286151975393295, -0.009953444823622704, -0.025637879967689514, 0.02820744179189205, 0.0018071745289489627, -0.052459489554166794, -0.030257316306233406, 0.03707098960876465, 0.010754628106951714, 0.030430546030402184, -0.00095817242981866, 0.012400303035974503, 0.03308672457933426, -0.03060377575457096, 0.0275722686201334, -0.010725757107138634, 0.04339384287595749, -0.016297953203320503, -0.02370348945260048, -0.023443646728992462, 0.019892454147338867, -0.051535602658987045, -0.024526327848434448, 0.02212999388575554, 0.02604207955300808, -0.005269045941531658, 0.011151611804962158, 0.07085062563419342, -0.03620484471321106, 0.040448952466249466, 0.006362553685903549, -0.049947671592235565, -0.03727308660745621, 0.014233642257750034, 0.016269082203507423, 0.03256703540682793, -0.041979141533374786, -0.02842397801578045, 0.021581435576081276, 0.0006053989636711776, -0.050669457763433456, -0.005204085260629654, -0.0082211559638381, -0.008776932023465633, -0.027168069034814835, 0.007622072473168373, -0.02758670412003994, -0.008885200135409832, 0.05367209389805794, 0.03704211488366127, -0.012147678062319756, -0.06270886957645416, 0.05681908503174782, 0.007022988982498646, 0.01892525888979435, -0.025479085743427277, -0.04887942597270012, 0.04327835887670517, -0.020210040733218193, 0.06484536081552505, 0.014298602938652039, -0.05728102847933769, -0.0019091269932687283, -0.00037984049413353205, -0.03144104778766632, 0.021653614938259125, 0.02197120152413845, 0.003471796168014407, 0.057829584926366806, 0.004186365287750959, -0.008986249566078186, -0.07471940666437149, 0.021422643214464188, 0.023891154676675797, 0.02751452662050724, 0.028048647567629814, 0.007448843214660883, 0.040535565465688705, -0.0017927387962117791, 0.027139196172356606, -0.035309828817 ...
#  TextNode(id_='e351fbc3-6448-4a9f-9950-990d1581ed52', embedding=[0.024927470833063126, 0.012845131568610668, -0.02105594053864479, -0.0033174261916428804, 0.04113320633769035, -0.014097262173891068, 0.019832594320178032, 0.04651592671871185, 0.02630913257598877, 0.030741961672902107, 0.040096960961818695, -0.03885922208428383, -0.035232361406087875, 0.011571412906050682, 0.024869902059435844, 0.038312312215566635, -0.01206075120717287, -0.028511153534054756, -0.03923342004418373, -7.286103937076405e-05, 0.06534106284379959, 0.05702230706810951, 0.026668939739465714, 0.013895769603550434, -0.011211604811251163, -0.029993562027812004, -0.054374124854803085, -0.01036965474486351, -0.017644964158535004, -0.023732909932732582, -0.008397909812629223, -0.04513426497578621, -0.0021264629904180765, -0.05638904869556427, -0.02439495548605919, 0.04280271381139755, -0.04962466284632683, -0.031001022085547447, -0.01799038052558899, 0.004396848846226931, -0.004731469787657261, 0.07996363937854767, 0.045997802168130875, 0.0032796463929116726, 0.03315986692905426, -0.01850850321352482, -0.03431125357747078, 0.020264364778995514, 0.00176035868935287, 0.04104685038328171, -0.04303298890590668, 0.06631973385810852, 0.0330447293817997, 0.00962845142930746, -0.0121614970266819, -0.008433890528976917, 0.012305419892072678, -0.012974661774933338, 0.020566603168845177, -0.002113869646564126, 0.031202515587210655, -0.022998901084065437, -0.027733970433473587, 0.04913532733917236, -0.018925879150629044, -0.02573343925178051, -0.025071393698453903, 0.0031501154880970716, -0.00797333661466837, -0.054633185267448425, 0.02534484677016735, 0.04654471203684807, -0.01715562678873539, 0.007548763416707516, 0.02394879423081875, -0.003133924212306738, 0.017573002725839615, -0.018709994852542877, -0.05518009513616562, 0.05132295563817024, -0.036786727607250214, 0.02144453302025795, -0.042083095759153366, -0.0051308562979102135, -0.010297693312168121, 0.010448812507092953, -0.025963716208934784, 0.002437696559354663, -0.07063742727041245, 0.010959739796817303, -0.029475439339876175, 0.038571376353502274, 0.058288831263780594, 0.03730485215783119, 0.016234518960118294, 0.03189334645867348, -0.05305003374814987, 0.019314471632242203, -0.03149035945534706, -0.0071853576228022575, 0.013291292823851109, -0.010333674028515816, -0.06177176907658577, 0.0019105783430859447, 0.04858841747045517, -0.025704655796289444, 0.033131085336208344, -0.02579100802540779, 0.0019771428778767586, 0.02150210179388523, -0.04320569708943367, 0.016148164868354797, -0.04052872955799103, 0.03448396176099777, 0.02790667675435543, -0.0059080407954752445, -0.016176950186491013, 0.005375525448471308, -0.03039654530584812, -0.04268757253885269, -0.030367761850357056, 0.023977577686309814, 0.0057929023168981075, -0.01850850321352482, 0.04775366559624672, -0.015054349787533283, 0.006732000038027763, -0.029792068526148796, -0.08013635128736496, -0.04334961995482445, 0.03934855759143829, 0.01164337433874607, 0.043551113456487656, -0.08790819346904755, 0.01101011224091053, 0.011319546960294247, -0.023085255175828934, -0.024351779371500015, -0.007721471134573221, 0.012571677565574646, -0.014421088621020317, -0.023329924792051315, 0.009722001850605011, 0.00041377873276360333, -0.010549559257924557, 0.014982388354837894, 0.024222247302532196, 0.03390826657414436, -0.009707609191536903, 0.038427453488111496, -0.007448017131537199, 0.010384047403931618, 0.005019315984100103, -0.02982085384428501, 0.024150285869836807, -0.018666818737983704, 0.07933037728071213, 0.0177313182502985, -0.018652426078915596, -0.00267157144844532, 0.01780327968299389, -0.03635495901107788, 0.03180699050426483, 0.006760784890502691, -0.05492103099822998, 0.06470780074596405, 0.004843010101467371, -0.0018305211560800672, -0.05601484701037407, -0.005595008376985788, -0.006875923369079828, 0.04985494166612625, 0.004749460145831108, 0.04332083463668823, 0.08347536623477936, -0.02157406322658062, -0.014687346294522285, -0.0269280001521 ...
#  TextNode(id_='f6b38dc0-0749-4de0-b388-0588f21f81ee', embedding=[0.007450156845152378, 0.015242377296090126, -0.004005570895969868, 0.0007961542578414083, -0.013990422710776329, -0.06693510711193085, -0.025011729449033737, 0.03513682633638382, 0.05166536569595337, -0.01948397234082222, 0.0023140637204051018, -0.011979085393249989, -0.02540852315723896, 0.01948397234082222, 0.002137900795787573, -0.013388389721512794, 0.03614933788776398, -0.010364542715251446, -0.0852150171995163, 0.04452306777238846, -0.0399804562330246, 0.06720875948667526, -0.04074667766690254, 0.01280003972351551, -0.026694685220718384, 0.0234792809933424, 0.005835614167153835, 0.01349100936204195, 0.046876467764377594, -0.03751759231090546, 0.048463646322488785, -0.018745115026831627, 0.012286943383514881, -0.04627443477511406, -0.02261728048324585, -0.042169664055109024, 0.01687060296535492, 0.02103010192513466, 0.01191067323088646, 0.022849883884191513, 0.04767005518078804, 0.03571149334311485, -0.008818413130939007, -0.022370994091033936, -0.024915950372815132, 0.001041585230268538, 0.028979672119021416, 0.04720484837889671, -0.01532447338104248, 0.016637999564409256, -0.0017308444948866963, 0.020277561619877815, 0.01620015688240528, 0.02404026687145233, -0.03319390118122101, -0.04162236303091049, -0.034890539944171906, 0.005065969657152891, -0.008072713389992714, -0.038037531077861786, 0.011958561837673187, -0.05708366259932518, -0.02488858625292778, 0.048655200749635696, -0.036806099116802216, -0.0032461886294186115, 0.024313917383551598, 0.025531666353344917, -0.0043510557152330875, -0.027200939133763313, 0.046383894979953766, 0.01027560606598854, 0.035082098096609116, -0.03535574674606323, -0.044960908591747284, 0.00648895651102066, 0.011240227147936821, -0.04230649024248123, -0.03450743108987808, -0.0018659598426893353, -0.008059030398726463, -0.01702111028134823, -0.012663214467465878, -0.012061181478202343, -0.023889759555459023, -0.005623534321784973, -0.02960907109081745, -0.026188429445028305, -0.0330570787191391, -0.00417660316452384, -0.045672401785850525, -0.000946662446949631, 0.010501368902623653, -0.008106919936835766, 0.008811571635305882, 0.01773260533809662, -0.05166536569595337, 0.02067435532808304, -0.027214622125029564, -0.007990618236362934, 0.011240227147936821, -0.0006896867998875678, -0.045863959938287735, 0.022740423679351807, 0.012485340237617493, 0.013155786320567131, -0.03344018757343292, 0.007470680400729179, 0.027023065835237503, -0.019538702443242073, -0.03231821954250336, -0.01893666945397854, 0.01175332348793745, 0.08641908317804337, -0.025805318728089333, 0.021467944607138634, 0.021180611103773117, -0.02160477079451084, 0.013388389721512794, -0.009413604624569416, -0.018649335950613022, -0.029280688613653183, 0.026886239647865295, -0.029718531295657158, 0.0009988272795453668, 0.01106235384941101, 0.01967552863061428, -0.02157740481197834, -0.03806489706039429, -0.018663018941879272, -0.000379691191483289, -0.022042611613869667, 0.060476936399936676, -0.04630180075764656, -0.025148555636405945, -0.02679046243429184, 0.01667904667556286, -0.045316655188798904, 0.004207388963550329, -0.01566653698682785, -0.021139563992619514, 0.019059812650084496, -0.015926506370306015, 0.005538018420338631, -0.0002080177509924397, 0.010364542715251446, -0.025175919756293297, 0.02352032996714115, 0.027980845421552658, 0.007279124576598406, -0.0165148563683033, -0.02993745170533657, 0.0007345827179960907, -0.01531079038977623, -0.025299062952399254, -0.06321345269680023, 0.07350274175405502, 0.05845191702246666, 0.025805318728089333, -0.0036669273395091295, -0.04939405992627144, 0.00764855369925499, -0.02867865562438965, -0.005425137002021074, 0.019265051931142807, 0.010227717459201813, -0.017513683065772057, -0.0556333102285862, -0.07569195330142975, -0.022904613986611366, 0.03740813210606575, -0.03426114469766617, 0.020086005330085754, -0.0113017987459898, 0.004912040662020445, 0.01985340192914009, 0.035246286541223526, 0.032071933150 ...
#  TextNode(id_='d77be865-3ceb-4a88-815c-3856a174fa32', embedding=[0.013551930896937847, 0.039208367466926575, -0.04890274628996849, 0.005601195618510246, 0.01744987815618515, -0.053049784153699875, -0.05644281581044197, 0.03177601099014282, 0.03963923081755638, 0.0014549980405718088, 0.01618422381579876, -0.03802350163459778, -0.0876263976097107, -0.016265010461211205, 0.025380417704582214, 0.07168453186750412, 0.02674032188951969, 0.0074188909493386745, -0.032287660986185074, 0.019106000661849976, -0.009175997227430344, 0.03363410010933876, -0.01131010614335537, -0.019415682181715965, -0.0402047336101532, 0.02154305949807167, 0.006651419680565596, -0.014622352086007595, 0.04004316031932831, -0.06252872943878174, 0.027453936636447906, -0.025380417704582214, 0.04647915065288544, -0.013538466766476631, -0.032772380858659744, 0.015511002391576767, -0.004436523653566837, -0.007021691184490919, 0.01758452318608761, 0.0017335431184619665, 0.04806794971227646, 0.03271852061152458, 0.016291938722133636, -0.034657396376132965, 0.0012925835326313972, 0.007863217033445835, -0.006250853184610605, 0.018957892432808876, -0.012791191227734089, 0.0063888635486364365, -0.0161976870149374, 0.040797170251607895, 0.01852703094482422, 0.045671287924051285, -0.017261376604437828, -0.02657875046133995, 0.0036959811113774776, -0.02155652455985546, 0.03942379727959633, 0.02420901320874691, 0.018500102683901787, -0.057466112077236176, -0.040177807211875916, 0.008139236830174923, -0.019711898639798164, -0.06613719463348389, 0.012151632457971573, -0.005638222675770521, -0.014635816216468811, -0.04728701710700989, 0.05967427417635918, 0.001997782150283456, 0.011767895892262459, -0.0037834998220205307, -0.027440471574664116, 0.011276445351541042, 0.03331095725297928, -0.02940627560019493, -0.008065182715654373, 0.00973477028310299, -0.02765590324997902, 0.019536862149834633, -0.037700355052948, -0.011895808391273022, -0.03185679763555527, -0.0024235942400991917, -0.028167549520730972, 0.007486212998628616, -0.05606581270694733, -0.03815814480185509, -0.007553535047918558, 0.0575738251209259, 0.05687367543578148, 0.013437483459711075, -0.000527215888723731, -0.015349430032074451, -0.05585038289427757, 0.01664201356470585, -0.04090488329529762, -7.983975956449285e-05, 0.02986406534910202, 0.026497963815927505, -0.03778114169836044, -0.008193095214664936, 0.025043806061148643, -0.02136802300810814, -0.035896122455596924, -0.02690189518034458, 0.002657538279891014, -0.009714573621749878, -0.05967427417635918, 0.01883671246469021, -0.009613590314984322, 0.04389398545026779, -0.037969641387462616, 0.008159433491528034, 0.01761145144701004, -0.0009736453066579998, -0.025743955746293068, 0.011996791698038578, -0.036380842328071594, 0.008455650880932808, 0.008085379377007484, -0.006634589284658432, -0.0036757844500243664, -0.023199182003736496, 0.03522290289402008, -0.0006155761075206101, -0.04475570470094681, -0.025878600776195526, -0.017180589959025383, 0.04750244691967964, 0.013693307526409626, -0.06629876792430878, -0.03603076562285423, -0.011969862505793571, 0.030914289876818657, -0.055904239416122437, -0.021166056394577026, -0.009492410346865654, -0.039854660630226135, -0.07615471631288528, 0.021139126271009445, 0.01344421599060297, 0.012966228649020195, 0.023845473304390907, 0.012131435796618462, 0.018311601132154465, -0.030564215034246445, 0.041578106582164764, -0.0027635705191642046, 0.005813260097056627, -0.007492945529520512, 0.005385764874517918, -0.02089676819741726, -0.026848038658499718, 0.04688308387994766, 0.022579818964004517, -0.04305918887257576, -0.0007885096129029989, -0.03172215446829796, 0.005722375120967627, 0.004372567869722843, -0.0003915198612958193, 0.008065182715654373, 0.0027113959658890963, -0.01573989726603031, -0.017369091510772705, -0.0641983151435852, -0.012952764518558979, 0.053696077316999435, -0.019240645691752434, 0.020156225189566612, 0.03255694732069969, -0.006940904539078474, 0.007270782720297575, -0.003766669426113367, -0. ...
#  TextNode(id_='7086d367-115f-4871-8905-0816c02604db', embedding=[0.010856731794774532, 0.010292843915522099, -0.024420129135251045, 0.012751397676765919, 0.013375434093177319, -0.04709596186876297, -0.024450203403830528, 0.026465164497494698, 0.02070598304271698, 0.008368104696273804, 0.03284086287021637, -0.030374791473150253, -0.04342692717909813, 0.008119993843138218, -0.013375434093177319, 0.045020852237939835, 0.03816397115588188, -0.016931690275669098, -0.053982920944690704, 0.025953905656933784, 0.027427533641457558, 0.038675229996442795, 0.03611893579363823, -0.006157661788165569, -0.012375472113490105, 0.007439568173140287, -0.015533247031271458, 0.002935979049652815, 0.05593773350119591, -0.0204052422195673, 0.037231672555208206, -0.032991234213113785, 0.014089692384004593, -0.027698200196027756, -0.05768202990293503, 0.03353256732225418, 8.534686639904976e-05, -0.004721625708043575, 0.04487048462033272, 0.0008495919173583388, 0.025006573647260666, 0.06844853609800339, 0.0028138032648712397, -0.006428328342735767, 0.02879590354859829, -0.015390395186841488, 0.0002716062590479851, 0.03305138275027275, 0.010608620941638947, 0.026465164497494698, -0.006183976773172617, 0.03401375189423561, 0.01983383670449257, -0.020675908774137497, 0.0007556105265393853, -0.013886692933738232, -0.003996089566498995, -0.018826356157660484, 0.029322199523448944, 0.012398026883602142, 0.0175482090562582, -0.08402689546346664, -0.005417088512331247, 0.0379534512758255, -0.027217015624046326, -0.04736663028597832, -0.00188432727009058, 0.015924209728837013, 0.049080848693847656, -0.040209006518125534, 0.04896055534482002, 0.02820945903658867, -0.000938874261919409, 0.015397913753986359, -0.00909740012139082, 0.0190669484436512, 0.03392352908849716, -0.023758498951792717, -0.0003883781610056758, 0.006980938836932182, -0.024420129135251045, 0.007766623515635729, -0.027382422238588333, 0.018645910546183586, -0.01092439889907837, -0.015367839485406876, -0.00967632606625557, 0.02263072319328785, -0.05497536435723305, -0.020826280117034912, -0.021818723529577255, 0.047727517783641815, 0.040630042552948, 0.02398405596613884, 0.03708130493760109, -0.012367953546345234, -0.02735234797000885, -0.008586141280829906, -0.011195065453648567, -0.017412874847650528, -0.009112437255680561, -0.0178188756108284, -0.040028560906648636, 0.023457759991288185, 0.02793879248201847, -0.03305138275027275, -0.0030675530433654785, -0.03702115640044212, 0.022314945235848427, -0.02986353263258934, -0.0525694414973259, -0.004413366783410311, -0.020916501060128212, 0.04438930004835129, -0.005650162231177092, -0.013172433711588383, -0.02205931581556797, 0.005811810027807951, -0.0042329225689172745, -0.039727821946144104, -0.03897596895694733, 0.02138265036046505, -0.003691589692607522, -0.032299529761075974, 0.0054809958674013615, 0.012240138836205006, 0.007289197761565447, -0.013112286105751991, -0.07909475266933441, -0.010608620941638947, 0.02849516272544861, 0.010398102924227715, 0.00218976684845984, -0.07957593351602554, -0.03329197317361832, -0.008721474558115005, 0.028299681842327118, -0.022119464352726936, -0.02505168318748474, -0.03702115640044212, -0.032991234213113785, -0.04363744705915451, -0.02541257254779339, -0.008119993843138218, -0.0016371561214327812, 0.005672717932611704, 0.021051835268735886, 0.025502795353531837, -0.03768278658390045, 0.030750716105103493, -0.005823087878525257, 0.0016352764796465635, -0.024615610018372536, 0.0016211792826652527, -0.03455508500337601, -0.026991460472345352, 0.0612909160554409, -0.0021672111470252275, -0.029592866078019142, -0.0032198030967265368, -0.023578055202960968, -0.014901692047715187, 0.02120220474898815, 0.01204465702176094, -0.007142587099224329, -0.00599601399153471, 0.008751548826694489, 0.013773915357887745, -0.07512497901916504, -0.050614625215530396, 0.026916274800896645, 0.005195292178541422, 0.029427457600831985, 0.009210177697241306, 0.023953981697559357, -0.009082362987101078, 0.03681063652038574, -0.0 ...

# %%
print(nodes[0])
# Out:
# Node ID: a6473a45-e86f-4211-89fb-e51ae7293a95
# Text: Product 1: Mesh Office Chair Mid Back Swivel Ergonomic Home
# Desk Chair with Flip-up Arms    Description:   ● The computer desk
# chair is made of the high-density and breathable mesh  back with
# lumbar support and thick cushion to provide you the most  comfortable
# posture. The thickened explosion-proof seat plate give you more
# comfort and double ...

# %% [markdown]
# ### **Retrieve Content from the Vector Store**

# %%
client = openai.OpenAI(api_key=openai_api_key)

# %%
# query the vector store with the 5 queries above (don't forget to record the responses in your homework submission!)

k = 5
queries = [
    "Summarize the product description and customer reviews in a concise bullet-point format highlighting the key features and overall user sentiment for mesh office chair.",
    "Summarize the product description and customer reviews in a concise bullet-point format highlighting the key features and overall user sentiment Dell monitor.",
    "Summarize the product description and customer reviews in a concise bullet-point format highlighting the key features and overall user sentiment Bomber jacket.",
    "Based on customer reviews, identify the key visual features of this office chair, including its material, color, shape, armrest design, backrest style, and any additional ergonomic details.",
    "Extract the visual characteristics of this Dell monitor from customer reviews, including screen size, bezel thickness, color, stand design, and any notable display features.",
    "Analyze customer reviews to determine the key visual features of this bomber jacket, such as material (e.g., leather, nylon), color options, fit (slim or oversized), collar style, pocket placement, and any distinctive design elements."
]
responses = []


# Choose one of these models:
embed_model_ada = "text-embedding-ada-002"
embed_model_3_small = "text-embedding-3-small"

for query in tqdm(queries):
    res = client.embeddings.create(
        input=[query],
        model=embed_model_ada
    )

    # Retrieve from Pinecone
    xq = res.data[0].embedding  # res['data'][0]['embedding']

    # Get relevant contexts (including the questions)
    res2 = pc_index.query(vector=xq, top_k=k, include_metadata=True)

    # Add response results
    responses.append(res2)
# Out:
# 100%|██████████| 6/6 [00:03<00:00,  1.98it/s]

# %%
chat_responses = []
for query, response in zip(queries, responses):
    chat_response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Instruction: use the information in {response} to answer the user's question."},
        {"role": "user", "content": query},
        {"role": "assistant", "content": str(response)},
        {"role": "user", "content": "What is the answer?"}
    ]
    )
    chat_responses.append(chat_response.choices[0].message.content)

# %%
print(chat_responses[0])
# Out:
# Here is a summary of the product description and customer reviews for a mesh office chair:
#
# **Product Features:**
# - Ergonomic design with adjustable height and tilt functions.
# - Breathable mesh back for comfort and temperature regulation.
# - Durable construction with a sturdy base and smooth-rolling casters.
# - Lumbar support for improved posture during long hours of sitting.
# - Contoured seat cushion for enhanced comfort.
#
# **Customer Reviews and Sentiment:**
# - Generally positive feedback on comfort and support, particularly for extended use.
# - Many users appreciate the breathability of the mesh material.
# - Complaints mainly involve assembly difficulties and durability of certain components.
# - Overall satisfaction is high, with several reviewers noting the chair's good value for the price.
#
# This summarizes key features and overall user sentiment for the mesh office chair.

# %%
print(chat_responses[1])
# Out:
# **Dell Monitor Summary:**
#
# - **Key Features:**
#   - 27-inch 4K UHD IPS display for vivid clarity.
#   - Ultra-thin bezel design for immersive viewing.
#   - AMD FreeSync technology for smooth visuals.
#   - Connectivity options include HDMI and DisplayPort.
#
# - **Customer Reviews:**
#   - Positive feedback on build quality, clear picture, and ease of setup.
#   - Color accuracy and picture quality praised, particularly for photo and video editing.
#   - Some users report issues with color calibration and compatibility with M1 MacBook Pro.
#   - Mixed experiences with customer service; some issues with replacements and setup instructions.
#   - Overall sentiment is generally positive with some exceptions.

# %%
print(chat_responses[2])
# Out:
# - **Product Description:**
#   - High visibility insulated bomber jacket designed for road work and construction.
#   - Features a weatherproof polyester shell with a quilted lining.
#   - Includes a concealed hood, zipper front closure, and reflective material.
#   - Offers 5 pockets including a cell phone/radio chest pocket with a clear panel.
#   - Available in a range of sizes from Small to 6XLarge.
#
# - **Customer Reviews:**
#   - General satisfaction with the jacket's warmth, quality, and visibility.
#   - Mixed feedback on the hood; some find it bulky or not very functional.
#   - Positive comments on fast shipping and good material quality.
#   - Some issues with sizing discrepancies and customer service responsiveness.
#   - Overall, most customers find the jacket to offer good value and effectiveness for its purpose.

# %%
print(chat_responses[3])
# Out:
# Based on customer reviews, the key visual features of the office chair include:
#
# - **Material**: Made from high-quality fabric or synthetic leather, providing durability and comfort.
# - **Color**: Comes in a variety of colors, often including black, grey, and other neutral tones to match office decor.
# - **Shape**: Ergonomically designed with a contoured seat and backrest to support the body.
# - **Armrest Design**: Features adjustable armrests that can be raised or lowered for optimal comfort.
# - **Backrest Style**: Typically includes a mesh backrest for breathability or a padded backrest for added comfort.
# - **Additional Ergonomic Details**: Includes features like lumbar support, adjustable tilt and height mechanisms, and a swivel base with caster wheels for easy movement.
#
# These features are intended to provide comfort during long hours of sitting and to fit various body types and preferences.

# %%
print(chat_responses[4])
# Out:
# The visual characteristics of the Dell monitor based on customer reviews include:
#
# - **Screen Size:** The monitor is described as being large and suitable for productivity tasks but no specific size is mentioned.
# - **Bezel Thickness:** The monitor has a minimal bezel with about 3/8-inch at the top and sides, and about 3/4-inch at the bottom, offering a nearly full-screen display experience.
# - **Color:** The color quality is described positively, with colors being true and accurate, although some customers experienced issues with color calibration.
# - **Stand Design:** Initially wobbly for some, but stable once the connection between the base and the post is tightened as per the set-up instructions.
# - **Notable Display Features:** The monitor offers a crisp, sharp picture with effective anti-glare coating. It does not support USB-C/Thunderbolt connectivity, limiting it to HDMI and DisplayPort. There are some compatibility issues with M1 MacBook Pros, and it's noted for having bright default settings that can be adjusted.

# %%
print(chat_responses[5])
# Out:
# The reviews highlight several key visual features of the bomber jacket:
#
# 1. **Material**: The jacket has a weatherproof polyester shell with a quilted lining.
# 2. **Color Options**: It is available in a high visibility lime green with a black bottom.
# 3. **Fit**: It does not specify if it's slim or oversized, but it's available in sizes ranging from Small to 6XL.
# 4. **Collar Style**: It includes a concealed hood, but no specific collar style is mentioned.
# 5. **Pocket Placement**: There are a total of 5 pockets, with 4 on the outside and 1 on the inside. There is a cell phone/radio chest pocket with a clear panel.
# 6. **Distinctive Design Elements**: The jacket features 2" silver reflective material, mic tabs, and pencil pockets, indicating that it is designed for high visibility and work utility.
#
# Overall, the jacket is designed for road work or construction with safety and functionality in mind.

# %%
# query the vector store with the 5 queries above (don't forget to record the responses in your homework submission!)

k = 5
queries = [
    "Summarize the product description and customer reviews in a concise bullet-point format highlighting the key features and overall user sentiment for mesh office chair.",
    "Summarize the product description and customer reviews in a concise bullet-point format highlighting the key features and overall user sentiment Dell monitor.",
    "Summarize the product description and customer reviews in a concise bullet-point format highlighting the key features and overall user sentiment Bomber jacket.",
    "Based on customer reviews, identify the key visual features of this office chair, including its material, color, shape, armrest design, backrest style, and any additional ergonomic details in 70 tokens.",
    "Extract the visual characteristics of this Dell monitor from customer reviews, including screen size, bezel thickness, color, stand design, and any notable display features in 70 tokens.",
    "Analyze customer reviews to determine the key visual features of this bomber jacket, such as material (e.g., leather, nylon), color options, fit (slim or oversized), collar style, pocket placement, and any distinctive design elements in 70 tokens."
]
responses = []


# Choose one of these models:
embed_model_ada = "text-embedding-ada-002"
embed_model_3_small = "text-embedding-3-small"

for query in tqdm(queries):
    res = client.embeddings.create(
        input=[query],
        model=embed_model_ada
    )

    # Retrieve from Pinecone
    xq = res.data[0].embedding  # res['data'][0]['embedding']

    # Get relevant contexts (including the questions)
    res2 = pc_index.query(vector=xq, top_k=k, include_metadata=True)

    # Add response results
    responses.append(res2)
# Out:
# 100%|██████████| 6/6 [00:04<00:00,  1.25it/s]

# %%
chat_responses = []
for query, response in zip(queries, responses):
    chat_response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Instruction: use the information in {response} to answer the user's question."},
        {"role": "user", "content": query},
        {"role": "assistant", "content": str(response)},
        {"role": "user", "content": "What is the answer?"}
    ]
    )
    chat_responses.append(chat_response.choices[0].message.content)

# %%
print(chat_responses[3])
# Out:
# Based on customer reviews, the key visual features of this office chair include its sleek, ergonomic shape designed for comfort. Commonly made with breathable mesh material, it often comes in neutral colors like black or gray to fit various office aesthetics. The chair features adjustable armrests to support different arm positions and a contoured backrest that provides lumbar support for better posture. Ergonomic details like height adjustment, tilt tension control, and a swivel base contribute to its functionality, making it a popular choice for office workers seeking both style and comfort.

# %%
print(chat_responses[4])
# Out:
# The Dell monitor is noted for its 27-inch screen size with a 4K UHD IPS display, known for remarkable clarity and vibrant colors. It features an ultra-thin bezel offering an immersive viewing experience. The monitor’s color accuracy and picture quality are highlighted, especially for photo and high-quality video work. It includes AMD FreeSync technology for smooth visuals, making it ideal for both work and play. The stand design is sturdy, with additional connectivity options including HDMI and DisplayPort, enhancing its functionality as a modern, adaptable monitor.

# %%
print(chat_responses[5])
# Out:
# The bomber jacket is typically made of weatherproof polyester with a quilted lining. It is available in high visibility lime green with a black bottom. The fit is not specified, but it is available in various sizes from Small to 6XLarge. The jacket features a zipper front closure and comes with an attachable, concealed hood. For storage, it includes five pockets: four on the outside and one inside, with a cell phone/radio chest pocket featuring a clear panel. Additionally, the jacket has mic tabs, a pencil pocket, and meets ANSI/ISEA 107-2015 Type R, Class 3 standards.
